# %% [markdown]
# # **📊 1: How many locations are in the game?**

# %%
# %sql
SELECT COUNT (DISTINCT *) AS total_locations 
FROM eldenringcatalog.gold.dim_locations;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>total_locations</th></tr></thead><tbody><tr><td>281</td></tr></tbody></table></div>

# %%
# %sql
SELECT location_id, location_name 
FROM eldenringcatalog.gold.dim_locations
LIMIT 10 ;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>location_id</th><th>location_name</th></tr></thead><tbody><tr><td>0</td><td>Abandoned Ailing Village</td></tr><tr><td>1</td><td>Artist's Shack (Gravesite Plain)</td></tr><tr><td>2</td><td>Belurat Gaol</td></tr><tr><td>3</td><td>Belurat Tower Settlement</td></tr><tr><td>4</td><td>Castle Ensis</td></tr><tr><td>5</td><td>Church of Benediction</td></tr><tr><td>6</td><td>Church of Consolation</td></tr><tr><td>7</td><td>Dragon's Pit</td></tr><tr><td>8</td><td>Elder's Hovel</td></tr><tr><td>9</td><td>Ellac Greatbridge</td></tr></tbody></table></div>

# %% [markdown]
# **Based on the data we currently have, the eldenringcatalog.gold.dim_locations table contains 281 distinct locations from Elden Ring. These include well-known areas such as Abandoned Ailing Village, Artist’s Shack (Gravesite Plain), Belurat Gaol, Castle Ensis, and Ellac Greatbridge. This dataset provides broad coverage of the world, but future updates may refine or expand the list as more official information becomes available.**

# %% [markdown]
# # **📊 2: Load NPCs and count total**

# %%
# %sql
SELECT COUNT(DISTINCT *) AS total_npcs 
FROM eldenringcatalog.gold.dim_npcs;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>total_npcs</th></tr></thead><tbody><tr><td>62</td></tr></tbody></table></div>

# %%
# %sql
SELECT npc_name, role, is_dlc 
FROM eldenringcatalog.gold.dim_npcs 
LIMIT 30;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>npc_name</th><th>role</th><th>is_dlc</th></tr></thead><tbody><tr><td>Abandoned Merchant Siofra River</td><td>General Goods Shop</td><td>0</td></tr><tr><td>Aeonian Spirit</td><td>Benevolent</td><td>0</td></tr><tr><td>Aeonian Swamp Spirit</td><td>Benevolent</td><td>0</td></tr><tr><td>Albinauric Village Spirit</td><td>Benevolent</td><td>0</td></tr><tr><td>Albus</td><td>Gives Key Item</td><td>0</td></tr><tr><td>Sir Ansbach</td><td>Pureblood Knight Captain (former), NPC Quest Related</td><td>1</td></tr><tr><td>Ashen Spirit</td><td>Benevolent</td><td>0</td></tr><tr><td>Blackguard Big Boggart</td><td>Blackguard</td><td>0</td></tr><tr><td>Blaidd the Half-Wolf</td><td>Quest NPC and summon</td><td>0</td></tr><tr><td>Bloody Finger Hunter Yura</td><td>Quest NPC and Summonable Cooperator</td><td>0</td></tr><tr><td>Boc the Seamster</td><td>Garments Adjuster andQuest NPC</td><td>0</td></tr><tr><td>Brother Corhyn</td><td>Merchant and Quest NPC</td><td>0</td></tr><tr><td>Carian Manor Spirit</td><td>Benevolent</td><td>0</td></tr><tr><td>Church of Pilgrimage Spirit</td><td>Spirit NPC</td><td>0</td></tr><tr><td>Count Ymir, High Priest</td><td>Merchant</td><td>1</td></tr><tr><td>D, Beholder of Death</td><td>Quest NPC and Summon</td><td>0</td></tr><tr><td>D, Hunter of the Dead</td><td>Quest NPC and Summon</td><td>0</td></tr><tr><td>Deathtouched Spirit</td><td>Spirit NPC</td><td>0</td></tr><tr><td>Knight Diallos</td><td>Quest NPC</td><td>0</td></tr><tr><td>Dragon Communion Priestess</td><td>Questline Related</td><td>1</td></tr><tr><td>Dryleaf Dane</td><td>Mini-Boss</td><td>1</td></tr><tr><td>Dung Eater</td><td>Quest NPC, Invader, and Summon</td><td>0</td></tr><tr><td>Eclipse Spirit</td><td>Spirit NPC</td><td>0</td></tr><tr><td>Edgar</td><td>Morne Castellan, Quest NPC</td><td>0</td></tr><tr><td>Enia</td><td>Finger Reader</td><td>0</td></tr><tr><td>Ensha of the Royal Remains</td><td>NPC Invader</td><td>0</td></tr><tr><td>Erdtree Sanctuary Spirit</td><td>Benevolent</td><td>0</td></tr><tr><td>Fia, Deathbed Companion</td><td>Quest NPC</td><td>0</td></tr><tr><td>Finger Maiden Therolina</td><td>NPC Summon</td><td>0</td></tr><tr><td>Fire Knight Queelign</td><td>NPC Invader, NPC</td><td>1</td></tr></tbody></table></div>

# %% [markdown]
# **Based on the data available in our dataset, Elden Ring contains 62 unique NPCs, covering a wide range of roles such as quest-related characters, merchants, invaders, benevolent spirits, and summonable allies. The preview shows a diverse mix, including key figures like Blaidd, Dung Eater, Fia, Enia, and various spirits and merchants. The dataset also indicates which NPCs belong to the DLC, such as Sir Ansbach, Count Ymir, and Dryleaf Dane. These insights reflect the current version of the data, and any missing or newly added NPCs may appear in future updates.**

# %% [markdown]
# # **📊 3: NPC roles distribution**

# %%
# %sql
SELECT 
    role,
    COUNT( DISTINCT *) AS npc_count
FROM eldenringcatalog.gold.dim_npcs
GROUP BY role
ORDER BY npc_count DESC;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>role</th><th>npc_count</th></tr></thead><tbody><tr><td>Quest NPC</td><td>8</td></tr><tr><td>Merchant</td><td>5</td></tr><tr><td>Quest NPC and Summon</td><td>4</td></tr><tr><td>General Goods Shop</td><td>3</td></tr><tr><td>Quest NPC and Summonable Cooperator</td><td>2</td></tr><tr><td>Guide and Quest NPC</td><td>1</td></tr><tr><td>Mini-Boss</td><td>1</td></tr><tr><td>Spirit-Tuner</td><td>1</td></tr><tr><td>NPC and Summonable Cooperator</td><td>1</td></tr><tr><td>Guide and Lore NPC</td><td>1</td></tr><tr><td>NPC Quest Related</td><td>1</td></tr><tr><td>Gives Key Item</td><td>1</td></tr><tr><td>Blacksmith & Quest NPC</td><td>1</td></tr><tr><td>Drake Warrior, NPC Quest Related</td><td>1</td></tr><tr><td>Elder Sage</td><td>1</td></tr><tr><td>Boss, Merchant, Quest NPC, Summon</td><td>1</td></tr><tr><td>Blackguard</td><td>1</td></tr><tr><td>Maiden</td><td>1</td></tr><tr><td>Quest NPC and Merchant</td><td>1</td></tr><tr><td>The Storyteller</td><td>1</td></tr><tr><td>Last Carian Queen</td><td>1</td></tr><tr><td>Scout</td><td>1</td></tr><tr><td>Special Trader</td><td>1</td></tr><tr><td>Merchant, Quest NPC, and Summon</td><td>1</td></tr><tr><td>Merchant, NPC Quest Related</td><td>1</td></tr><tr><td>Blacksmith</td><td>1</td></tr><tr><td>Garments Adjuster andQuest NPC</td><td>1</td></tr><tr><td>Questline Related</td><td>1</td></tr><tr><td>Quest NPC and summon</td><td>1</td></tr><tr><td>Hornsent Survivor</td><td>1</td></tr><tr><td>Ash of War Merchant</td><td>1</td></tr><tr><td>Quest NPC, Invader, and Summon</td><td>1</td></tr><tr><td>Servant of Count Ymir</td><td>1</td></tr><tr><td>Next Rightful Ruler of Limgrave</td><td>1</td></tr><tr><td>Amicable NPC, Invader NPC</td><td>1</td></tr><tr><td>Finger Reader</td><td>1</td></tr><tr><td>Morne Castellan, Quest NPC</td><td>1</td></tr><tr><td>Miquella's Followers Leader</td><td>1</td></tr><tr><td>Pureblood Knight Captain (former), NPC Quest Related</td><td>1</td></tr><tr><td>NPC Invader, NPC</td><td>1</td></tr><tr><td>Merchant and Quest NPC</td><td>1</td></tr><tr><td>Main NPC - Affects Endings</td><td>1</td></tr><tr><td>Sorcery Student</td><td>1</td></tr><tr><td>NPC and Merchant</td><td>1</td></tr><tr><td>Cooperator, Questline Related</td><td>1</td></tr><tr><td>NPC Summon</td><td>0</td></tr><tr><td>First Demigod to die</td><td>0</td></tr><tr><td>Ruler of The Lands Between</td><td>0</td></tr><tr><td>NPC</td><td>0</td></tr><tr><td>Messenger of The Greater Will</td><td>0</td></tr><tr><td>Spirit NPC</td><td>0</td></tr><tr><td>Summon and Boss</td><td>0</td></tr><tr><td>NPC Invader</td><td>0</td></tr><tr><td>Benevolent</td><td>0</td></tr><tr><td>null</td><td>0</td></tr><tr><td>Ending of Millicent questline</td><td>0</td></tr><tr><td>God Greater Will Manifestation</td><td>0</td></tr></tbody></table></div>

# %% [markdown]
# **The NPC roles in Elden Ring are highly varied, with Quest NPCs being the most common (8), followed by Merchants (5) and hybrid roles like Quest NPC and Summon (4). Many roles appear only once, reflecting unique or story-specific characters, such as Blacksmith & Quest NPC, The Storyteller, or Miquella's Followers Leader. Several entries have zero counts or inconsistent labeling, highlighting the need for standardization of role categories to improve analysis and avoid duplicates or null/ambiguous entries. This would make role-based insights clearer and more actionable.**

# %% [markdown]
# # **📊 4: DLC NPCs vs base game**

# %%
# %sql
SELECT 
    CASE WHEN is_dlc = 1 THEN 'DLC' ELSE 'Base Game' END AS content_type,
    COUNT(DISTINCT *) AS npc_count
FROM eldenringcatalog.gold.dim_npcs
GROUP BY is_dlc;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>content_type</th><th>npc_count</th></tr></thead><tbody><tr><td>Base Game</td><td>48</td></tr><tr><td>DLC</td><td>14</td></tr></tbody></table></div>

# %% [markdown]
# **In Elden Ring, most NPCs are from the Base Game (48), while a smaller portion belongs to DLC content (14). This shows that the majority of characters players encounter are part of the core game, with DLC adding a more limited but potentially unique set of NPCs.**

# %% [markdown]
# # **📊 5: Load items and analyze item types**

# %%
# %sql
SELECT COUNT(DISTINCT *) AS total_items 
FROM eldenringcatalog.gold.dim_items;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>total_items</th></tr></thead><tbody><tr><td>584</td></tr></tbody></table></div>

# %%
# %sql
SELECT 
    item_type,
    COUNT(DISTINCT *) AS item_count
FROM eldenringcatalog.gold.dim_items
GROUP BY item_type
ORDER BY item_count DESC
limit 5;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>item_type</th><th>item_count</th></tr></thead><tbody><tr><td>Consumable</td><td>209</td></tr><tr><td>Cookbook</td><td>106</td></tr><tr><td>Material</td><td>105</td></tr><tr><td>Bell</td><td>60</td></tr><tr><td>Upgrade Material</td><td>42</td></tr></tbody></table></div>

# %% [markdown]
# **In Elden Ring, the game features 584 distinct items. The most common item types are Consumables (209), Cookbooks (106), and Materials (105), followed by Bells (60) and Upgrade Materials (42). This indicates that healing, crafting, and upgrade mechanics play a major role in gameplay.**

# %% [markdown]
# # **📊 6: Load location-items bridge table**

# %%
# %sql
SELECT COUNT(DISTINCT *) AS total_relationships 
FROM eldenringcatalog.gold.bridge_location_items;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>total_relationships</th></tr></thead><tbody><tr><td>2937</td></tr></tbody></table></div>

# %%
# %sql
SELECT * 
FROM eldenringcatalog.gold.bridge_location_items 
LIMIT 20;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>location_item_key</th><th>location_id</th><th>item_name</th><th>created_at</th></tr></thead><tbody><tr><td>0</td><td>0</td><td>Broken Rune</td><td>2025-11-29T17:01:17.003Z</td></tr><tr><td>1</td><td>0</td><td>Golden Rune (1)</td><td>2025-11-29T17:01:17.003Z</td></tr><tr><td>2</td><td>0</td><td>Black Pyrefly</td><td>2025-11-29T17:01:17.003Z</td></tr><tr><td>3</td><td>0</td><td>Human Bone Shard</td><td>2025-11-29T17:01:17.003Z</td></tr><tr><td>4</td><td>0</td><td>Fly Mold</td><td>2025-11-29T17:01:17.003Z</td></tr><tr><td>5</td><td>0</td><td>Ailment Talisman</td><td>2025-11-29T17:01:17.003Z</td></tr><tr><td>6</td><td>0</td><td>Revered Spirit Ash</td><td>2025-11-29T17:01:17.003Z</td></tr><tr><td>7</td><td>0</td><td>Greater Potentates Cookbook (10)</td><td>2025-11-29T17:01:17.003Z</td></tr><tr><td>8</td><td>0</td><td>Larval Tear</td><td>2025-11-29T17:01:17.003Z</td></tr><tr><td>9</td><td>1</td><td>Incursion Painting</td><td>2025-11-29T17:01:17.003Z</td></tr><tr><td>10</td><td>2</td><td>Frozen Maggot</td><td>2025-11-29T17:01:17.003Z</td></tr><tr><td>11</td><td>2</td><td>Broken Rune</td><td>2025-11-29T17:01:17.003Z</td></tr><tr><td>12</td><td>2</td><td>Shadow Realm Rune 3</td><td>2025-11-29T17:01:17.003Z</td></tr><tr><td>13</td><td>2</td><td>Smithing Stone 3</td><td>2025-11-29T17:01:17.003Z</td></tr><tr><td>14</td><td>2</td><td>Smithing Stone 6</td><td>2025-11-29T17:01:17.003Z</td></tr><tr><td>15</td><td>2</td><td>Greatjar</td><td>2025-11-29T17:01:17.003Z</td></tr><tr><td>16</td><td>2</td><td>Glass Shard</td><td>2025-11-29T17:01:17.003Z</td></tr><tr><td>17</td><td>2</td><td>Innard Meat</td><td>2025-11-29T17:01:17.003Z</td></tr><tr><td>18</td><td>2</td><td>Thawfrost Boluses</td><td>2025-11-29T17:01:17.003Z</td></tr><tr><td>19</td><td>2</td><td>Silver Horn Tender</td><td>2025-11-29T17:01:17.003Z</td></tr></tbody></table></div>

# %% [markdown]
# **The bridge_location_items table in Elden Ring contains 2,937 distinct relationships linking locations to items. Each record represents a specific item found at a particular location, including its creation timestamp. For example, location 0 has items like Broken Rune, Golden Rune (1), and Black Pyrefly, while location 2 includes items such as Frozen Maggot, Smithing Stone 3, and Innard Meat. This table is essential for tracking item distribution and accessibility across the game world.**

# %% [markdown]
# # **📊 7: Which location has the most items?**

# %%
# %sql
SELECT 
    l.location_name,
    l.location_id,
    COUNT(DISTINCT *) AS item_count
FROM eldenringcatalog.gold.bridge_location_items b
JOIN eldenringcatalog.gold.dim_locations l ON b.location_id = l.location_id
GROUP BY l.location_name, l.location_id
ORDER BY item_count DESC
LIMIT 20
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>location_name</th><th>location_id</th><th>item_count</th></tr></thead><tbody><tr><td>Leyndell, Royal Capital</td><td>230</td><td>84</td></tr><tr><td>Stormveil Castle</td><td>81</td><td>82</td></tr><tr><td>Raya Lucaria Academy</td><td>144</td><td>64</td></tr><tr><td>Volcano Manor</td><td>217</td><td>53</td></tr><tr><td>Elphael Brace of the Haligtree</td><td>263</td><td>50</td></tr><tr><td>Subterranean Shunning-Grounds</td><td>284</td><td>41</td></tr><tr><td>Siofra River</td><td>283</td><td>40</td></tr><tr><td>Nokron, Eternal City</td><td>280</td><td>39</td></tr><tr><td>Deeproot Depths</td><td>272</td><td>38</td></tr><tr><td>Castle Morne</td><td>90</td><td>34</td></tr><tr><td>Miquella's Haligtree</td><td>266</td><td>32</td></tr><tr><td>Ainsel River</td><td>270</td><td>29</td></tr><tr><td>Mohgwyn Palace</td><td>277</td><td>28</td></tr><tr><td>Mistwood</td><td>70</td><td>27</td></tr><tr><td>The Shaded Castle</td><td>200</td><td>27</td></tr><tr><td>Lake of Rot</td><td>276</td><td>26</td></tr><tr><td>Caria Manor</td><td>115</td><td>24</td></tr><tr><td>Jarburg</td><td>132</td><td>24</td></tr><tr><td>Nokstella, Eternal City</td><td>281</td><td>21</td></tr><tr><td>Fort of Reprimand</td><td>28</td><td>20</td></tr></tbody></table></div>

# %% [markdown]
# **The top 20 locations in Elden Ring with the most unique items show that Leyndell, Royal Capital leads with 84 unique items, followed closely by Stormveil Castle with 82 unique items and Raya Lucaria Academy with 64 unique items. Other notable locations include Volcano Manor (53 unique items), Elphael Brace of the Haligtree (50 unique items), and Subterranean Shunning-Grounds (41 unique items). This highlights that major castles, academies, and late-game areas tend to contain the densest concentration of unique collectible items.**

# %% [markdown]
# # **📊 8: Locations with fewest items**

# %%
# %sql
SELECT 
    l.location_name,
    l.location_id,
    COUNT(DISTINCT *) AS item_count
FROM eldenringcatalog.gold.bridge_location_items b
JOIN eldenringcatalog.gold.dim_locations l ON b.location_id = l.location_id
GROUP BY l.location_name, l.location_id
ORDER BY item_count
LIMIT 20;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>location_name</th><th>location_id</th><th>item_count</th></tr></thead><tbody><tr><td>Castle Ensis</td><td>4</td><td>0</td></tr><tr><td>Belurat Tower Settlement</td><td>3</td><td>0</td></tr><tr><td>Midra's Manse</td><td>46</td><td>0</td></tr><tr><td>Enir-Ilim</td><td>25</td><td>0</td></tr><tr><td>Shadow Keep</td><td>33</td><td>0</td></tr><tr><td>Sellia Evergaol</td><td>240</td><td>1</td></tr><tr><td>Malefactor's Evergaol</td><td>137</td><td>1</td></tr><tr><td>Golden Lineage Evergaol</td><td>187</td><td>1</td></tr><tr><td>Cuckoo's Evergaol</td><td>125</td><td>1</td></tr><tr><td>Forlorn Hound Evergaol</td><td>62</td><td>1</td></tr><tr><td>Ranni's Rise</td><td>143</td><td>1</td></tr><tr><td>Whipping Hut</td><td>35</td><td>1</td></tr><tr><td>Albinauric Rise</td><td>259</td><td>1</td></tr><tr><td>Oridys's Rise</td><td>100</td><td>1</td></tr><tr><td>Frenzy-Flaming Tower</td><td>129</td><td>1</td></tr><tr><td>The Four Belfries</td><td>158</td><td>1</td></tr><tr><td>Wailing Dunes</td><td>182</td><td>1</td></tr><tr><td>Artist's Shack (Gravesite Plain)</td><td>1</td><td>1</td></tr><tr><td>Royal Grave Evergaol</td><td>151</td><td>1</td></tr><tr><td>Suppressing Pillar</td><td>17</td><td>1</td></tr></tbody></table></div>

# %% [markdown]
# **The bottom 20 locations in Elden Ring, in terms of unique items, show that many areas have very few or no items at all. Locations like Castle Ensis, Belurat Tower Settlement, Midra's Manse, Enir-Ilim, and Shadow Keep have 0 unique items, while others such as Sellia Evergaol, Malefactor's Evergaol, and Golden Lineage Evergaol have only 1 unique item. This suggests that smaller dungeons, minor towers, or less-explored zones generally offer minimal loot compared to major castles and academies.**

# %% [markdown]
# # **📊 9: Load location-NPCs bridge table**

# %%
# %sql
SELECT COUNT(DISTINCT *) AS total_relationships 
FROM eldenringcatalog.gold.bridge_location_npcs;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>total_relationships</th></tr></thead><tbody><tr><td>215</td></tr></tbody></table></div>

# %%
# %sql
SELECT DISTINCT * 
FROM eldenringcatalog.gold.bridge_location_npcs 
LIMIT 20;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>location_npc_key</th><th>location_id</th><th>npc_name</th><th>created_at</th></tr></thead><tbody><tr><td>0</td><td>0</td><td>Spirit NPC</td><td>2025-11-29T17:01:19.511Z</td></tr><tr><td>1</td><td>3</td><td>Moore</td><td>2025-11-29T17:01:19.511Z</td></tr><tr><td>2</td><td>3</td><td>Sir Ansbach</td><td>2025-11-29T17:01:19.511Z</td></tr><tr><td>3</td><td>3</td><td>Hornsent Grandam</td><td>2025-11-29T17:01:19.511Z</td></tr><tr><td>4</td><td>4</td><td>Rellana</td><td>2025-11-29T17:01:19.511Z</td></tr><tr><td>5</td><td>4</td><td>Twin Moon Knight</td><td>2025-11-29T17:01:19.511Z</td></tr><tr><td>6</td><td>8</td><td>Spirit NPC</td><td>2025-11-29T17:01:19.511Z</td></tr><tr><td>7</td><td>14</td><td>Spirit NPC</td><td>2025-11-29T17:01:19.511Z</td></tr><tr><td>8</td><td>16</td><td>Spirit NPC</td><td>2025-11-29T17:01:19.511Z</td></tr><tr><td>9</td><td>21</td><td>Count Ymir</td><td>2025-11-29T17:01:19.511Z</td></tr><tr><td>10</td><td>21</td><td>Jolan</td><td>2025-11-29T17:01:19.511Z</td></tr><tr><td>11</td><td>22</td><td>Fire Knight Queelign</td><td>2025-11-29T17:01:19.511Z</td></tr><tr><td>12</td><td>25</td><td>Moore</td><td>2025-11-29T17:01:19.511Z</td></tr><tr><td>13</td><td>25</td><td>Thiollier</td><td>2025-11-29T17:01:19.511Z</td></tr><tr><td>14</td><td>25</td><td>Sir Ansbach</td><td>2025-11-29T17:01:19.511Z</td></tr><tr><td>15</td><td>25</td><td>Dryleaf Dane</td><td>2025-11-29T17:01:19.511Z</td></tr><tr><td>16</td><td>25</td><td>Redmane Freyja</td><td>2025-11-29T17:01:19.511Z</td></tr><tr><td>17</td><td>25</td><td>Needle Knight Leda</td><td>2025-11-29T17:01:19.511Z</td></tr><tr><td>18</td><td>26</td><td>Swordhand of Night Anna</td><td>2025-11-29T17:01:19.511Z</td></tr><tr><td>19</td><td>29</td><td>Dryleaf Dane</td><td>2025-11-29T17:01:19.511Z</td></tr></tbody></table></div>

# %% [markdown]
# **The bridge_location_npcs table contains 215 unique relationships between locations and NPCs in Elden Ring. The sample shows that some locations host multiple NPCs, like location 3 with characters such as Moore, Sir Ansbach, and Hornsent Grandam, while other locations may only host a single NPC or a generic Spirit NPC. This table effectively maps which NPCs appear in which locations, helping to track quests, summons, and interactions across the game world.**

# %% [markdown]
# # **📊 10: Which locations have the most NPCs?**

# %%
# %sql
SELECT 
    l.location_name,
    l.location_id,
    COUNT(DISTINCT*) AS npc_count
FROM eldenringcatalog.gold.bridge_location_npcs b
JOIN eldenringcatalog.gold.dim_locations l ON b.location_id = l.location_id
GROUP BY l.location_name, l.location_id
ORDER BY npc_count DESC
LIMIT 20;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>location_name</th><th>location_id</th><th>npc_count</th></tr></thead><tbody><tr><td>Roundtable Hold</td><td>52</td><td>14</td></tr><tr><td>Seethewater Cave</td><td>215</td><td>13</td></tr><tr><td>Bestial Sanctum</td><td>232</td><td>11</td></tr><tr><td>Sealed Tunnel</td><td>225</td><td>7</td></tr><tr><td>Raya Lucaria Academy</td><td>144</td><td>6</td></tr><tr><td>Volcano Manor</td><td>217</td><td>5</td></tr><tr><td>Leyndell, Royal Capital</td><td>230</td><td>5</td></tr><tr><td>Stormveil Castle</td><td>81</td><td>4</td></tr><tr><td>Ranni's Rise</td><td>143</td><td>4</td></tr><tr><td>Deeproot Depths</td><td>272</td><td>3</td></tr><tr><td>Stone Coffin Fissure</td><td>41</td><td>3</td></tr><tr><td>Stormfoot Catacombs</td><td>76</td><td>3</td></tr><tr><td>Stormhill</td><td>78</td><td>3</td></tr><tr><td>Siofra River</td><td>283</td><td>3</td></tr><tr><td>Leyndell, Ashen Capital</td><td>229</td><td>3</td></tr><tr><td>Mistwood</td><td>70</td><td>3</td></tr><tr><td>Redmane Castle</td><td>173</td><td>3</td></tr><tr><td>Gowry's Shack</td><td>170</td><td>2</td></tr><tr><td>Bellum Church</td><td>111</td><td>2</td></tr><tr><td>Academy Gate Town</td><td>108</td><td>2</td></tr></tbody></table></div>

# %% [markdown]
# **The top 20 locations with the most NPCs show that Roundtable Hold leads with 14 NPCs, followed by Seethewater Cave with 13 and Bestial Sanctum with 11. Many major areas like Raya Lucaria Academy, Leyndell, Royal Capital, and Volcano Manor host 5–6 NPCs each, indicating these locations are key hubs for interactions, quests, and gameplay events. Smaller locations tend to host 3–4 NPCs, reflecting a mix of major quest areas and minor exploration zones. This distribution highlights the concentration of NPCs in central hubs versus spread-out adventuring areas.**

# %% [markdown]
# # **📊 11: Load location-bosses bridge table**

# %%
# %sql
SELECT COUNT(DISTINCT *) AS total_relationships 
FROM eldenringcatalog.gold.bridge_location_bosses
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>total_relationships</th></tr></thead><tbody><tr><td>235</td></tr></tbody></table></div>

# %%
# %sql
SELECT DISTINCT * 
FROM eldenringcatalog.gold.bridge_location_bosses 
LIMIT 20;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>location_boss_key</th><th>location_id</th><th>boss_name</th><th>created_at</th></tr></thead><tbody><tr><td>0</td><td>2</td><td>Demi-Human Swordmaster Onze</td><td>2025-11-29T17:01:24.609Z</td></tr><tr><td>1</td><td>3</td><td>Divine Beast Dancing Lion</td><td>2025-11-29T17:01:24.609Z</td></tr><tr><td>2</td><td>4</td><td>Rellanas Cameo</td><td>2025-11-29T17:01:24.609Z</td></tr><tr><td>3</td><td>4</td><td>Spelldrake Talisman</td><td>2025-11-29T17:01:24.609Z</td></tr><tr><td>4</td><td>7</td><td>Ancient Dragon-Man</td><td>2025-11-29T17:01:24.609Z</td></tr><tr><td>5</td><td>10</td><td>Black Knight Garrew</td><td>2025-11-29T17:01:24.609Z</td></tr><tr><td>6</td><td>11</td><td>Red Bear</td><td>2025-11-29T17:01:24.609Z</td></tr><tr><td>7</td><td>13</td><td>Chief Bloodfiend</td><td>2025-11-29T17:01:24.609Z</td></tr><tr><td>8</td><td>18</td><td>Blackgaol Knight</td><td>2025-11-29T17:01:24.609Z</td></tr><tr><td>9</td><td>19</td><td>Curseblade Labirith</td><td>2025-11-29T17:01:24.609Z</td></tr><tr><td>10</td><td>21</td><td>Count Ymir</td><td>2025-11-29T17:01:24.609Z</td></tr><tr><td>11</td><td>21</td><td>Mother of Fingers</td><td>2025-11-29T17:01:24.609Z</td></tr><tr><td>12</td><td>21</td><td>Swordhand of Night Anna</td><td>2025-11-29T17:01:24.609Z</td></tr><tr><td>13</td><td>21</td><td>Swordhand of Night Jolan</td><td>2025-11-29T17:01:24.609Z</td></tr><tr><td>14</td><td>22</td><td>Fire Knight Queelign</td><td>2025-11-29T17:01:24.609Z</td></tr><tr><td>15</td><td>23</td><td>Jori</td><td>2025-11-29T17:01:24.609Z</td></tr><tr><td>16</td><td>23</td><td>Elder Inquisitor</td><td>2025-11-29T17:01:24.609Z</td></tr><tr><td>17</td><td>24</td><td>Rakshasa</td><td>2025-11-29T17:01:24.609Z</td></tr><tr><td>18</td><td>25</td><td>Promised Consort Radahn</td><td>2025-11-29T17:01:24.609Z</td></tr><tr><td>19</td><td>25</td><td>Radahn</td><td>2025-11-29T17:01:24.609Z</td></tr></tbody></table></div>

# %% [markdown]
# **The bridge_location_bosses table contains 235 unique boss-location relationships, showing which bosses appear in which locations. The sample of 20 rows highlights that some locations host multiple bosses, such as location_id 21, which contains Count Ymir, Mother of Fingers, and Swordhand of Night Anna and Jolan. Other locations host a single boss, like Demi-Human Swordmaster Onze at location 2. This indicates that boss encounters are unevenly distributed, with certain locations serving as major challenge hubs.**

# %% [markdown]
# # **📊 12: Which locations have multiple bosses?**

# %%
# %sql
SELECT 
    l.location_name,
    l.location_id,
    COUNT(DISTINCT *) AS boss_count
FROM eldenringcatalog.gold.bridge_location_bosses b
JOIN eldenringcatalog.gold.dim_locations l ON b.location_id = l.location_id
GROUP BY l.location_name, l.location_id
HAVING COUNT(*) > 1
ORDER BY boss_count DESC;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>location_name</th><th>location_id</th><th>boss_count</th></tr></thead><tbody><tr><td>Leyndell, Royal Capital</td><td>230</td><td>6</td></tr><tr><td>Leyndell, Ashen Capital</td><td>229</td><td>6</td></tr><tr><td>Volcano Manor</td><td>217</td><td>6</td></tr><tr><td>Elden Throne</td><td>226</td><td>4</td></tr><tr><td>Stormveil Castle</td><td>81</td><td>4</td></tr><tr><td>Ainsel River</td><td>270</td><td>4</td></tr><tr><td>Cathedral of Manus Metyr</td><td>21</td><td>4</td></tr><tr><td>Mistwood</td><td>70</td><td>3</td></tr><tr><td>Forbidden Lands</td><td>246</td><td>3</td></tr><tr><td>Stormhill</td><td>78</td><td>3</td></tr><tr><td>Lake of Rot</td><td>276</td><td>3</td></tr><tr><td>Moonlight Altar</td><td>141</td><td>3</td></tr><tr><td>Nokron, Eternal City</td><td>280</td><td>3</td></tr><tr><td>Raya Lucaria Academy</td><td>144</td><td>3</td></tr><tr><td>Redmane Castle</td><td>173</td><td>3</td></tr><tr><td>Yelough Anix Tunnel</td><td>269</td><td>2</td></tr><tr><td>Altus Tunnel</td><td>184</td><td>2</td></tr><tr><td>Grand Cloister</td><td>274</td><td>2</td></tr><tr><td>Perfumer's Grotto</td><td>194</td><td>2</td></tr><tr><td>Mohgwyn Palace</td><td>277</td><td>2</td></tr><tr><td>Bestial Sanctum</td><td>232</td><td>2</td></tr><tr><td>Miquella's Haligtree</td><td>266</td><td>2</td></tr><tr><td>Fringefolk Hero's Grave</td><td>64</td><td>2</td></tr><tr><td>Malefactor's Evergaol</td><td>137</td><td>2</td></tr><tr><td>Hallowhorn Grounds</td><td>275</td><td>2</td></tr><tr><td>Darklight Catacombs</td><td>23</td><td>2</td></tr><tr><td>Cuckoo's Evergaol</td><td>125</td><td>2</td></tr><tr><td>Black Knife Catacombs</td><td>113</td><td>2</td></tr><tr><td>Sage's Cave</td><td>196</td><td>2</td></tr><tr><td>Roundtable Hold</td><td>52</td><td>2</td></tr><tr><td>Mohgwyn Dynasty Mausoleum</td><td>278</td><td>2</td></tr><tr><td>Auriza Hero's Grave</td><td>218</td><td>2</td></tr><tr><td>Siofra River</td><td>283</td><td>2</td></tr><tr><td>Leyndell Catacombs</td><td>227</td><td>2</td></tr><tr><td>Ringleader's Evergaol</td><td>148</td><td>2</td></tr><tr><td>Elphael Brace of the Haligtree</td><td>263</td><td>2</td></tr><tr><td>Finger Ruins of Miyr</td><td>26</td><td>2</td></tr><tr><td>Castle Ensis</td><td>4</td><td>0</td></tr><tr><td>Midra's Manse</td><td>46</td><td>0</td></tr><tr><td>Enir-Ilim</td><td>25</td><td>0</td></tr></tbody></table></div>

# %% [markdown]
# **Several locations in Elden Ring host multiple bosses, making them key challenge areas. Leyndell, Royal Capital, Leyndell, Ashen Capital, and Volcano Manor top the list with 6 bosses each, followed by Elden Throne, Stormveil Castle, and Ainsel River with 4 bosses. Other locations like Mistwood, Raya Lucaria Academy, and Redmane Castle have 3 bosses, while many smaller or optional areas host 2. This distribution shows that some major hubs concentrate multiple boss encounters, whereas other locations may only feature a single or no boss.**

# %% [markdown]
# # **📊 13: Load location-creatures bridge table**

# %%
# %sql
SELECT COUNT(DISTINCT *) AS total_relationships
FROM eldenringcatalog.gold.bridge_location_creatures;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>total_relationships</th></tr></thead><tbody><tr><td>789</td></tr></tbody></table></div>

# %%
# %sql
SELECT DISTINCT *
FROM eldenringcatalog.gold.bridge_location_creatures
LIMIT 20;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>location_creature_key</th><th>location_id</th><th>creature_name</th><th>created_at</th></tr></thead><tbody><tr><td>0</td><td>0</td><td>Man-Fly</td><td>2025-11-29T17:01:22.030Z</td></tr><tr><td>1</td><td>2</td><td>Living Jar</td><td>2025-11-29T17:01:22.030Z</td></tr><tr><td>2</td><td>2</td><td>Jar Innards</td><td>2025-11-29T17:01:22.030Z</td></tr><tr><td>3</td><td>2</td><td>Shadow Undead</td><td>2025-11-29T17:01:22.030Z</td></tr><tr><td>4</td><td>2</td><td>Messmer Foot Soldier</td><td>2025-11-29T17:01:22.030Z</td></tr><tr><td>5</td><td>3</td><td>Man-Fly</td><td>2025-11-29T17:01:22.030Z</td></tr><tr><td>6</td><td>3</td><td>Gravebird</td><td>2025-11-29T17:01:22.030Z</td></tr><tr><td>7</td><td>3</td><td>Curseblade</td><td>2025-11-29T17:01:22.030Z</td></tr><tr><td>8</td><td>3</td><td>Horned Warrior</td><td>2025-11-29T17:01:22.030Z</td></tr><tr><td>9</td><td>3</td><td>Spider Scorpion</td><td>2025-11-29T17:01:22.030Z</td></tr><tr><td>10</td><td>3</td><td>Shadow Undead</td><td>2025-11-29T17:01:22.030Z</td></tr><tr><td>11</td><td>3</td><td>Fire Knight Queelign</td><td>2025-11-29T17:01:22.030Z</td></tr><tr><td>12</td><td>3</td><td>Lesser Ulcerated Tree Spirit</td><td>2025-11-29T17:01:22.030Z</td></tr><tr><td>13</td><td>4</td><td>Page</td><td>2025-11-29T17:01:22.030Z</td></tr><tr><td>14</td><td>4</td><td>Eagle</td><td>2025-11-29T17:01:22.030Z</td></tr><tr><td>15</td><td>4</td><td>Turtle</td><td>2025-11-29T17:01:22.030Z</td></tr><tr><td>16</td><td>4</td><td>Rotten Stray</td><td>2025-11-29T17:01:22.030Z</td></tr><tr><td>17</td><td>4</td><td>Troll Knight</td><td>2025-11-29T17:01:22.030Z</td></tr><tr><td>18</td><td>4</td><td>Messmer Soldier</td><td>2025-11-29T17:01:22.030Z</td></tr><tr><td>19</td><td>4</td><td>Noble Sorcerer</td><td>2025-11-29T17:01:22.030Z</td></tr></tbody></table></div>

# %% [markdown]
# **The bridge_location_creatures table in Elden Ring contains 789 unique location-creature relationships, mapping various creatures to the locations where they appear. A sample of 20 entries shows a wide variety of creatures, from "Man-Fly" and "Living Jar" to "Troll Knight" and "Noble Sorcerer," highlighting the diversity of enemies and entities populating the game world.**

# %% [markdown]
# # **📊 14: Which locations have the most creature variety?**

# %%
# %sql
SELECT 
    l.location_name,
    lc.location_id,
    COUNT(DISTINCT *) AS creature_count,
    COUNT(DISTINCT lc.creature_name) AS unique_creatures
FROM eldenringcatalog.gold.bridge_location_creatures lc
LEFT JOIN eldenringcatalog.gold.dim_locations l
    ON lc.location_id = l.location_id
GROUP BY l.location_name, lc.location_id
ORDER BY unique_creatures DESC
LIMIT 20;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>location_name</th><th>location_id</th><th>creature_count</th><th>unique_creatures</th></tr></thead><tbody><tr><td>Raya Lucaria Academy</td><td>144</td><td>22</td><td>22</td></tr><tr><td>Shadow Keep</td><td>33</td><td>0</td><td>14</td></tr><tr><td>Stormhill</td><td>78</td><td>14</td><td>14</td></tr><tr><td>Mistwood</td><td>70</td><td>14</td><td>14</td></tr><tr><td>Siofra River</td><td>283</td><td>13</td><td>13</td></tr><tr><td>The Shaded Castle</td><td>200</td><td>12</td><td>12</td></tr><tr><td>Castle Ensis</td><td>4</td><td>0</td><td>12</td></tr><tr><td>Moonlight Altar</td><td>141</td><td>11</td><td>11</td></tr><tr><td>Miquella's Haligtree</td><td>266</td><td>11</td><td>11</td></tr><tr><td>Volcano Manor</td><td>217</td><td>11</td><td>11</td></tr><tr><td>Swamp of Aeonia</td><td>181</td><td>10</td><td>10</td></tr><tr><td>Caria Manor</td><td>115</td><td>10</td><td>10</td></tr><tr><td>Dragon-Burnt Ruins</td><td>61</td><td>9</td><td>9</td></tr><tr><td>Enir-Ilim</td><td>25</td><td>0</td><td>9</td></tr><tr><td>Castle Morne</td><td>90</td><td>8</td><td>8</td></tr><tr><td>Belurat Tower Settlement</td><td>3</td><td>0</td><td>8</td></tr><tr><td>Stormveil Castle</td><td>81</td><td>8</td><td>8</td></tr><tr><td>Elphael Brace of the Haligtree</td><td>263</td><td>8</td><td>8</td></tr><tr><td>Minor Erdtree (Weeping Peninsula)</td><td>98</td><td>7</td><td>7</td></tr><tr><td>Nokstella, Eternal City</td><td>281</td><td>7</td><td>7</td></tr></tbody></table></div>

# %% [markdown]
# **The analysis of location-creature relationships in Elden Ring shows that Raya Lucaria Academy hosts the most diverse set of creatures with 22 unique types, followed by locations like Shadow Keep, Stormhill, and Mistwood, each featuring 14 distinct creatures. Several other areas, including Siofra River, The Shaded Castle, and Miquella's Haligtree, contain 10–13 unique creatures. Interestingly, some locations such as Castle Ensis, Enir-Ilim, and Belurat Tower Settlement have zero total creature entries despite still listing unique creature types. Overall, this highlights a mix of highly populated areas with rich creature diversity and more sparse locations across the Lands Between.**

# %% [markdown]
# # **📊 15: What are the most common creatures**?

# %%
# %sql
SELECT 
    creature_name,
    COUNT(DISTINCT *) AS location_count
FROM eldenringcatalog.gold.bridge_location_creatures
GROUP BY creature_name
ORDER BY location_count DESC
LIMIT 30;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>creature_name</th><th>location_count</th></tr></thead><tbody><tr><td>Map Link</td><td>24</td></tr><tr><td>Rotten Stray</td><td>21</td></tr><tr><td>Giant Rat</td><td>20</td></tr><tr><td>Miranda Sprout</td><td>14</td></tr><tr><td>Putrid Corpse</td><td>13</td></tr><tr><td>Giant Miranda Sprout</td><td>12</td></tr><tr><td>Wandering Nobles</td><td>12</td></tr><tr><td>Giant Bat</td><td>12</td></tr><tr><td>Teardrop Scarab</td><td>11</td></tr><tr><td>Rat</td><td>11</td></tr><tr><td>Soldier</td><td>11</td></tr><tr><td>Imp</td><td>10</td></tr><tr><td>Skeletal Slime</td><td>9</td></tr><tr><td>Demi-Human</td><td>9</td></tr><tr><td>Living Jar</td><td>9</td></tr><tr><td>Turtle</td><td>8</td></tr><tr><td>Giant Crab</td><td>8</td></tr><tr><td>Marionette Soldier</td><td>8</td></tr><tr><td>Fanged Imp</td><td>8</td></tr><tr><td>Shadow Undead</td><td>8</td></tr><tr><td>Misbegotten</td><td>8</td></tr><tr><td>Wolf</td><td>8</td></tr><tr><td>Sheep</td><td>7</td></tr><tr><td>Deer</td><td>7</td></tr><tr><td>Troll</td><td>7</td></tr><tr><td>Godrick Soldier</td><td>7</td></tr><tr><td>Godrick Knight</td><td>7</td></tr><tr><td>Messmer Soldier</td><td>7</td></tr><tr><td>Miner</td><td>7</td></tr><tr><td>Servant of Rot</td><td>7</td></tr></tbody></table></div>

# %% [markdown]
# **The creature distribution shows that several enemies appear across multiple locations in Elden Ring. Excluding the data issue with “Map Link,” the most common creatures are Rotten Stray (21 locations), Giant Rat (20), Miranda Sprout (14), and Putrid Corpse (13). Many other enemies, like Giant Miranda Sprout, Wandering Nobles, and Giant Bat, appear in 12 locations, indicating that certain enemy types are recurrent across the Lands Between, providing consistent challenges for players.**

# %% [markdown]
# # **📊 16: Rare creatures (appearing in only 1-2 locations**)

# %%
# %sql
SELECT 
    creature_name,
    COUNT(DISTINCT *) AS location_count
FROM eldenringcatalog.gold.bridge_location_creatures
GROUP BY creature_name
HAVING COUNT( *) <= 2
ORDER BY location_count ASC, creature_name ASC;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>creature_name</th><th>location_count</th></tr></thead><tbody><tr><td>Ash of War: Flame Skewer</td><td>1</td></tr><tr><td>Blistered Stray</td><td>1</td></tr><tr><td>Bloodhound Knight</td><td>1</td></tr><tr><td>Blue Worm</td><td>1</td></tr><tr><td>Burning Slug</td><td>1</td></tr><tr><td>Cat Imp</td><td>1</td></tr><tr><td>Cerulean Scarabs</td><td>1</td></tr><tr><td>Colossal Fingercreeper</td><td>1</td></tr><tr><td>Colossal Fingercreepers</td><td>1</td></tr><tr><td>Crimson Scarabs</td><td>1</td></tr><tr><td>Crimson Teardrop Scarab</td><td>1</td></tr><tr><td>Crystalians</td><td>1</td></tr><tr><td>Demi-Human Queen</td><td>1</td></tr><tr><td>Disciple of Okina</td><td>1</td></tr><tr><td>Divine Bird Warrior</td><td>1</td></tr><tr><td>Eagles</td><td>1</td></tr><tr><td>Edgar the Revenger</td><td>1</td></tr><tr><td>Eleonora</td><td>1</td></tr><tr><td>Festering Fingerprint Vyke</td><td>1</td></tr><tr><td>Festering Fingerprint Vyke (Invader)</td><td>1</td></tr><tr><td>Finger Mimic</td><td>1</td></tr><tr><td>Fingercreepers</td><td>1</td></tr><tr><td>Fire Knight</td><td>1</td></tr><tr><td>Fire Knight Captain Kood</td><td>1</td></tr><tr><td>Fire Knight Queelign</td><td>1</td></tr><tr><td>First-Generation Albinauric</td><td>1</td></tr><tr><td>Flame Guardian</td><td>1</td></tr><tr><td>Furnace Golem</td><td>1</td></tr><tr><td>Giant Beast Skeleton</td><td>1</td></tr><tr><td>Giant Dog</td><td>1</td></tr><tr><td>Giant Land Squirt</td><td>1</td></tr><tr><td>Giant Oracle Envoy</td><td>1</td></tr><tr><td>Giant Skeletal Slime</td><td>1</td></tr><tr><td>Glintstone Dragon</td><td>1</td></tr><tr><td>Godrick Foot Soldier</td><td>1</td></tr><tr><td>Grave Warden Duelist</td><td>1</td></tr><tr><td>Greater Potentate</td><td>1</td></tr><tr><td>Grossmesser</td><td>1</td></tr><tr><td>Haligtree Knight</td><td>1</td></tr><tr><td>Haligtree Soldier</td><td>1</td></tr><tr><td>High Page</td><td>1</td></tr><tr><td>Highwayman</td><td>1</td></tr><tr><td>Hippopotamus</td><td>1</td></tr><tr><td>Hornsent</td><td>1</td></tr><tr><td>Inaba</td><td>1</td></tr><tr><td>Inquisitor Ghiza</td><td>1</td></tr><tr><td>Knight of Zamor</td><td>1</td></tr><tr><td>Large Oracle Envoy </td><td>1</td></tr><tr><td>Lesser Black Knife Assassin</td><td>1</td></tr><tr><td>Lesser Black Knight</td><td>1</td></tr><tr><td>Lesser Cemetery Shade</td><td>1</td></tr><tr><td>Lesser Crystalian</td><td>1</td></tr><tr><td>Lesser Fingercreepers</td><td>1</td></tr><tr><td>Lesser Magma Wyrm</td><td>1</td></tr><tr><td>Lesser Sanguine Noble</td><td>1</td></tr><tr><td>Lesser Wormface</td><td>1</td></tr><tr><td>Lion Guardian</td><td>1</td></tr><tr><td>Living Jars</td><td>1</td></tr><tr><td>Mage-Serpent</td><td>1</td></tr><tr><td>Magnus the Beast Claw</td><td>1</td></tr><tr><td>Mausoleum Knight</td><td>1</td></tr><tr><td>Mausoleum Soldier</td><td>1</td></tr><tr><td>Moongrum</td><td>1</td></tr><tr><td>Moonrithyll</td><td>1</td></tr><tr><td>Nameless White Mask</td><td>1</td></tr><tr><td>Necromancer</td><td>1</td></tr><tr><td>Nomad</td><td>1</td></tr><tr><td>Nox Monk</td><td>1</td></tr><tr><td>Onyx Lord</td><td>1</td></tr><tr><td>Oracle Envoy</td><td>1</td></tr><tr><td>Owl</td><td>1</td></tr><tr><td>Poison Flowers</td><td>1</td></tr><tr><td>Putrid Avatar</td><td>1</td></tr><tr><td>Putrid Tree Spirit</td><td>1</td></tr><tr><td>Rats</td><td>1</td></tr><tr><td>Raya Lucaria Foot Soldier</td><td>1</td></tr><tr><td>Raya Lucaria Knight</td><td>1</td></tr><tr><td>Raya Lucaria Soldiers</td><td>1</td></tr><tr><td>Shadow Militia</td><td>1</td></tr><tr><td>Shadow Militiamen</td><td>1</td></tr><tr><td>Shadowpot</td><td>1</td></tr><tr><td>Skeletal Militiaman</td><td>1</td></tr><tr><td>Skeletal Militiamen</td><td>1</td></tr><tr><td>Soldier of Godrick</td><td>1</td></tr><tr><td>Starcaller</td><td>1</td></tr><tr><td>Thorn Sorcerer</td><td>1</td></tr><tr><td>Troll Spirit Knight</td><td>1</td></tr><tr><td>Valiant Gargoyle</ ...

# %% [markdown]
# # **📊 17: Item type distribution per location**

# %%
# %sql
SELECT 
    l.location_name,
    i.item_type,
    COUNT(DISTINCT *) AS item_count
FROM eldenringcatalog.gold.bridge_location_items bli
INNER JOIN eldenringcatalog.gold.dim_locations l ON bli.location_id = l.location_id
LEFT JOIN eldenringcatalog.gold.dim_items i ON bli.item_name = i.item_name
GROUP BY l.location_name, i.item_type
ORDER BY l.location_name, item_count DESC
LIMIT 50;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>location_name</th><th>item_type</th><th>item_count</th></tr></thead><tbody><tr><td>Abandoned Ailing Village</td><td>Material</td><td>3</td></tr><tr><td>Abandoned Ailing Village</td><td>Upgrade Material</td><td>1</td></tr><tr><td>Abandoned Ailing Village</td><td>null</td><td>0</td></tr><tr><td>Abandoned Ailing Village</td><td>Key Item</td><td>0</td></tr><tr><td>Abandoned Cave</td><td>Consumable</td><td>3</td></tr><tr><td>Abandoned Cave</td><td>Material</td><td>2</td></tr><tr><td>Abandoned Cave</td><td>null</td><td>0</td></tr><tr><td>Abandoned Church</td><td>Upgrade Material</td><td>0</td></tr><tr><td>Abandoned Church</td><td>null</td><td>0</td></tr><tr><td>Academy Crystal Cave</td><td>Material</td><td>4</td></tr><tr><td>Academy Crystal Cave</td><td>Consumable</td><td>2</td></tr><tr><td>Academy Crystal Cave</td><td>null</td><td>0</td></tr><tr><td>Academy Crystal Cave</td><td>Key Item</td><td>0</td></tr><tr><td>Academy Gate Town</td><td>Material</td><td>2</td></tr><tr><td>Academy Gate Town</td><td>Consumable</td><td>2</td></tr><tr><td>Academy Gate Town</td><td>Upgrade Material</td><td>1</td></tr><tr><td>Academy Gate Town</td><td>null</td><td>0</td></tr><tr><td>Ailing Village</td><td>Material</td><td>5</td></tr><tr><td>Ailing Village</td><td>Upgrade Material</td><td>1</td></tr><tr><td>Ailing Village</td><td>Consumable</td><td>1</td></tr><tr><td>Ailing Village</td><td>null</td><td>0</td></tr><tr><td>Ainsel River</td><td>Material</td><td>4</td></tr><tr><td>Ainsel River</td><td>Upgrade Material</td><td>1</td></tr><tr><td>Ainsel River</td><td>null</td><td>0</td></tr><tr><td>Ainsel River</td><td>Key Item</td><td>0</td></tr><tr><td>Ainsel River Main</td><td>Consumable</td><td>2</td></tr><tr><td>Ainsel River Main</td><td>Material</td><td>1</td></tr><tr><td>Ainsel River Main</td><td>Key Item</td><td>0</td></tr><tr><td>Ainsel River Main</td><td>null</td><td>0</td></tr><tr><td>Albinauric Rise</td><td>null</td><td>0</td></tr><tr><td>Albinauric's Shack</td><td>Material</td><td>1</td></tr><tr><td>Albinauric's Shack</td><td>null</td><td>0</td></tr><tr><td>Altus Tunnel</td><td>Material</td><td>2</td></tr><tr><td>Altus Tunnel</td><td>Consumable</td><td>2</td></tr><tr><td>Altus Tunnel</td><td>null</td><td>0</td></tr><tr><td>Apostate Derelict</td><td>null</td><td>0</td></tr><tr><td>Artist's Shack (Gravesite Plain)</td><td>null</td><td>0</td></tr><tr><td>Artist's Shack (Limgrave)</td><td>Material</td><td>4</td></tr><tr><td>Artist's Shack (Limgrave)</td><td>null</td><td>0</td></tr><tr><td>Artist's Shack (Liurnia of the Lakes)</td><td>null</td><td>0</td></tr><tr><td>Auriza Hero's Grave</td><td>Material</td><td>1</td></tr><tr><td>Auriza Hero's Grave</td><td>Ammo</td><td>0</td></tr><tr><td>Auriza Hero's Grave</td><td>Key Item</td><td>0</td></tr><tr><td>Auriza Hero's Grave</td><td>null</td><td>0</td></tr><tr><td>Auriza Side Tomb</td><td>Material</td><td>1</td></tr><tr><td>Auriza Side Tomb</td><td>null</td><td>0</td></tr><tr><td>Auriza Side Tomb</td><td>Key Item</td><td>0</td></tr><tr><td>Bellum Church</td><td>Material</td><td>1</td></tr><tr><td>Bellum Church</td><td>Upgrade Material</td><td>1</td></tr><tr><td>Bellum Church</td><td>Consumable</td><td>1</td></tr></tbody></table></div>

# %% [markdown]
# # **📊 18: Locations with most "Ammo" items**

# %%
# %sql
SELECT 
    l.location_name,
    COUNT(*) AS ammo_count
FROM eldenringcatalog.gold.bridge_location_items bli
INNER JOIN eldenringcatalog.gold.dim_items i ON bli.item_name = i.item_name
INNER JOIN eldenringcatalog.gold.dim_locations l ON bli.location_id = l.location_id
WHERE i.item_type = 'Ammo'
GROUP BY l.location_name
ORDER BY ammo_count DESC
LIMIT 20;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>location_name</th><th>ammo_count</th></tr></thead><tbody><tr><td>Hermit Merchant's Shack</td><td>7</td></tr><tr><td>Isolated Merchant's Shack Weeping Peninsula</td><td>4</td></tr><tr><td>Stormveil Castle</td><td>3</td></tr><tr><td>Isolated Merchant's Shack (Dragonbarrow)</td><td>3</td></tr><tr><td>Castle Morne</td><td>2</td></tr><tr><td>Elphael Brace of the Haligtree</td><td>2</td></tr><tr><td>Bridge of Sacrifice</td><td>2</td></tr><tr><td>Castle Ensis</td><td>2</td></tr><tr><td>Belurat Tower Settlement</td><td>2</td></tr><tr><td>Enir-Ilim</td><td>2</td></tr><tr><td>Miquella's Haligtree</td><td>1</td></tr><tr><td>Volcano Manor</td><td>1</td></tr><tr><td>Tower of Return</td><td>1</td></tr><tr><td>Bonny Gaol</td><td>1</td></tr><tr><td>Ellac Greatbridge</td><td>1</td></tr><tr><td>Stormcaller Church</td><td>1</td></tr><tr><td>Subterranean Shunning-Grounds</td><td>1</td></tr><tr><td>Deeproot Depths</td><td>1</td></tr><tr><td>Fog Rift Fort</td><td>1</td></tr><tr><td>Stillwater Cave</td><td>1</td></tr></tbody></table></div>

# %% [markdown]
# # **📊 19: Create location "density" score**

# %%
# %sql
WITH location_stats AS (
    SELECT 
        l.location_id,
        l.location_name,
        COALESCE(COUNT(DISTINCT bli.item_name), 0) AS item_count,
        COALESCE(COUNT(DISTINCT bln.npc_name), 0) AS npcs,
        COALESCE(COUNT(DISTINCT blb.boss_name), 0) AS bosses,
        COALESCE(COUNT(DISTINCT blc.creature_name), 0) AS creatures
    FROM eldenringcatalog.gold.dim_locations l
    LEFT JOIN eldenringcatalog.gold.bridge_location_items bli ON l.location_id = bli.location_id
    LEFT JOIN eldenringcatalog.gold.bridge_location_npcs bln ON l.location_id = bln.location_id
    LEFT JOIN eldenringcatalog.gold.bridge_location_bosses blb ON l.location_id = blb.location_id
    LEFT JOIN eldenringcatalog.gold.bridge_location_creatures blc ON l.location_id = blc.location_id
    GROUP BY l.location_id, l.location_name
)
SELECT 
    location_name,
    item_count,
    npcs,
    bosses,
    creatures,
    ROUND(item_count + (npcs * 5) + (bosses * 10) + (creatures * 0.5), 2) AS density_score
FROM location_stats
ORDER BY density_score DESC
LIMIT 30;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>location_name</th><th>item_count</th><th>npcs</th><th>bosses</th><th>creatures</th><th>density_score</th></tr></thead><tbody><tr><td>Leyndell, Royal Capital</td><td>75</td><td>5</td><td>6</td><td>1</td><td>160.5</td></tr><tr><td>Stormveil Castle</td><td>82</td><td>4</td><td>4</td><td>8</td><td>146.0</td></tr><tr><td>Volcano Manor</td><td>52</td><td>5</td><td>6</td><td>11</td><td>142.5</td></tr><tr><td>Raya Lucaria Academy</td><td>63</td><td>6</td><td>3</td><td>22</td><td>134.0</td></tr><tr><td>Shadow Keep</td><td>93</td><td>4</td><td>1</td><td>14</td><td>130.0</td></tr><tr><td>Enir-Ilim</td><td>53</td><td>6</td><td>3</td><td>9</td><td>117.5</td></tr><tr><td>Roundtable Hold</td><td>10</td><td>14</td><td>2</td><td>0</td><td>100.0</td></tr><tr><td>Seethewater Cave</td><td>18</td><td>13</td><td>1</td><td>6</td><td>96.0</td></tr><tr><td>Leyndell, Ashen Capital</td><td>14</td><td>3</td><td>6</td><td>3</td><td>90.5</td></tr><tr><td>Bestial Sanctum</td><td>12</td><td>11</td><td>2</td><td>0</td><td>87.0</td></tr><tr><td>Castle Ensis</td><td>47</td><td>2</td><td>2</td><td>12</td><td>83.0</td></tr><tr><td>Belurat Tower Settlement</td><td>52</td><td>3</td><td>1</td><td>8</td><td>81.0</td></tr><tr><td>Mistwood</td><td>27</td><td>3</td><td>3</td><td>14</td><td>79.0</td></tr><tr><td>Elphael Brace of the Haligtree</td><td>49</td><td>1</td><td>2</td><td>8</td><td>78.0</td></tr><tr><td>Siofra River</td><td>36</td><td>3</td><td>2</td><td>13</td><td>77.5</td></tr><tr><td>Nokron, Eternal City</td><td>39</td><td>1</td><td>3</td><td>7</td><td>77.5</td></tr><tr><td>Ainsel River</td><td>29</td><td>1</td><td>4</td><td>1</td><td>74.5</td></tr><tr><td>Redmane Castle</td><td>19</td><td>3</td><td>3</td><td>6</td><td>67.0</td></tr><tr><td>Stormhill</td><td>14</td><td>3</td><td>3</td><td>14</td><td>66.0</td></tr><tr><td>Cathedral of Manus Metyr</td><td>14</td><td>2</td><td>4</td><td>3</td><td>65.5</td></tr><tr><td>Mohgwyn Palace</td><td>28</td><td>2</td><td>2</td><td>6</td><td>61.0</td></tr><tr><td>Sealed Tunnel</td><td>13</td><td>7</td><td>1</td><td>4</td><td>60.0</td></tr><tr><td>Lake of Rot</td><td>26</td><td>0</td><td>3</td><td>5</td><td>58.5</td></tr><tr><td>Miquella's Haligtree</td><td>32</td><td>0</td><td>2</td><td>11</td><td>57.5</td></tr><tr><td>Moonlight Altar</td><td>16</td><td>1</td><td>3</td><td>11</td><td>56.5</td></tr><tr><td>Deeproot Depths</td><td>31</td><td>3</td><td>1</td><td>1</td><td>56.5</td></tr><tr><td>The Shaded Castle</td><td>27</td><td>2</td><td>1</td><td>12</td><td>53.0</td></tr><tr><td>Subterranean Shunning-Grounds</td><td>41</td><td>2</td><td>0</td><td>0</td><td>51.0</td></tr><tr><td>Caria Manor</td><td>24</td><td>2</td><td>1</td><td>10</td><td>49.0</td></tr><tr><td>Elden Throne</td><td>3</td><td>1</td><td>4</td><td>0</td><td>48.0</td></tr></tbody></table></div>

# %% [markdown]
# # **📊 20: Merchant NPCs and their locations**

# %%
# %sql
SELECT npc_name, role, is_dlc
FROM eldenringcatalog.gold.dim_npcs
WHERE role LIKE '%Merchant%' OR role LIKE '%Shop%';
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>npc_name</th><th>role</th><th>is_dlc</th></tr></thead><tbody><tr><td>Abandoned Merchant Siofra River</td><td>General Goods Shop</td><td>0</td></tr><tr><td>Brother Corhyn</td><td>Merchant and Quest NPC</td><td>0</td></tr><tr><td>Count Ymir, High Priest</td><td>Merchant</td><td>1</td></tr><tr><td>Gatekeeper Gostoc</td><td>NPC and Merchant</td><td>0</td></tr><tr><td>Hermit Merchant (Leyndell)</td><td>Merchant</td><td>0</td></tr><tr><td>Imprisoned Merchant</td><td>General Goods Shop</td><td>0</td></tr><tr><td>Isolated Merchant Raya Lucaria</td><td>General Goods Shop</td><td>0</td></tr><tr><td>Knight Bernahl</td><td>Ash of War Merchant</td><td>0</td></tr><tr><td>Merchant Kale</td><td>General Goods Shop</td><td>0</td></tr><tr><td>Miriel, Pastor of Vows</td><td>Merchant</td><td>0</td></tr><tr><td>Moore</td><td>Merchant</td><td>1</td></tr><tr><td>Nomadic Merchant Central ALTUS PLATEAU</td><td>General Goods Shop</td><td>0</td></tr><tr><td>Patches</td><td>Boss, Merchant, Quest NPC, Summon</td><td>0</td></tr><tr><td>Pidia, Carian Servant</td><td>Merchant</td><td>0</td></tr><tr><td>Preceptor Seluvis</td><td>Quest NPC and Merchant</td><td>0</td></tr><tr><td>Sorcerer Rogier</td><td>Merchant, Quest NPC, and Summon</td><td>0</td></tr><tr><td>Sorceress Sellen</td><td>Merchant and Quest NPC</td><td>0</td></tr><tr><td>Thiollier</td><td>Merchant, NPC Quest Related</td><td>1</td></tr><tr><td>Twin Maiden Husks</td><td>Merchant</td><td>0</td></tr></tbody></table></div>

# %%
# %sql
SELECT 
    n.npc_name,
    l.location_name,
    n.role
FROM eldenringcatalog.gold.dim_npcs n
LEFT JOIN eldenringcatalog.gold.bridge_location_npcs bln ON n.npc_name = bln.npc_name
LEFT JOIN eldenringcatalog.gold.dim_locations l ON bln.location_id = l.location_id
WHERE n.role LIKE '%Merchant%' OR n.role LIKE '%Shop%'
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>npc_name</th><th>location_name</th><th>role</th></tr></thead><tbody><tr><td>Abandoned Merchant Siofra River</td><td>null</td><td>General Goods Shop</td></tr><tr><td>Brother Corhyn</td><td>Leyndell, Royal Capital</td><td>Merchant and Quest NPC</td></tr><tr><td>Count Ymir, High Priest</td><td>null</td><td>Merchant</td></tr><tr><td>Gatekeeper Gostoc</td><td>Stormveil Castle</td><td>NPC and Merchant</td></tr><tr><td>Hermit Merchant (Leyndell)</td><td>null</td><td>Merchant</td></tr><tr><td>Imprisoned Merchant</td><td>Mohgwyn Dynasty Mausoleum</td><td>General Goods Shop</td></tr><tr><td>Isolated Merchant Raya Lucaria</td><td>null</td><td>General Goods Shop</td></tr><tr><td>Knight Bernahl</td><td>Volcano Manor</td><td>Ash of War Merchant</td></tr><tr><td>Merchant Kale</td><td>null</td><td>General Goods Shop</td></tr><tr><td>Miriel, Pastor of Vows</td><td>null</td><td>Merchant</td></tr><tr><td>Moore</td><td>Enir-Ilim</td><td>Merchant</td></tr><tr><td>Nomadic Merchant Central ALTUS PLATEAU</td><td>null</td><td>General Goods Shop</td></tr><tr><td>Patches</td><td>Volcano Manor</td><td>Boss, Merchant, Quest NPC, Summon</td></tr><tr><td>Pidia, Carian Servant</td><td>null</td><td>Merchant</td></tr><tr><td>Preceptor Seluvis</td><td>Seluvis's Rise</td><td>Quest NPC and Merchant</td></tr><tr><td>Sorcerer Rogier</td><td>Stormveil Castle</td><td>Merchant, Quest NPC, and Summon</td></tr><tr><td>Sorceress Sellen</td><td>Raya Lucaria Academy</td><td>Merchant and Quest NPC</td></tr><tr><td>Thiollier</td><td>Stone Coffin Fissure</td><td>Merchant, NPC Quest Related</td></tr><tr><td>Twin Maiden Husks</td><td>Roundtable Hold</td><td>Merchant</td></tr><tr><td>Brother Corhyn</td><td>Leyndell, Ashen Capital</td><td>Merchant and Quest NPC</td></tr><tr><td>Knight Bernahl</td><td>Warmaster's Shack</td><td>Ash of War Merchant</td></tr><tr><td>Moore</td><td>Belurat Tower Settlement</td><td>Merchant</td></tr><tr><td>Patches</td><td>The Shaded Castle</td><td>Boss, Merchant, Quest NPC, Summon</td></tr><tr><td>Preceptor Seluvis</td><td>Ranni's Rise</td><td>Quest NPC and Merchant</td></tr><tr><td>Sorcerer Rogier</td><td>Roundtable Hold</td><td>Merchant, Quest NPC, and Summon</td></tr><tr><td>Sorceress Sellen</td><td>Witchbane Ruins</td><td>Merchant and Quest NPC</td></tr><tr><td>Thiollier</td><td>Enir-Ilim</td><td>Merchant, NPC Quest Related</td></tr><tr><td>Knight Bernahl</td><td>Stormhill</td><td>Ash of War Merchant</td></tr><tr><td>Patches</td><td>Murkwater Cave</td><td>Boss, Merchant, Quest NPC, Summon</td></tr><tr><td>Sorceress Sellen</td><td>Waypoint Ruins</td><td>Merchant and Quest NPC</td></tr></tbody></table></div>

# %% [markdown]
# # **📊 21: Quest NPCs and their locations**

# %%
# %sql
SELECT npc_name, role, is_dlc
FROM eldenringcatalog.gold.dim_npcs
WHERE role LIKE '%Quest%';
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>npc_name</th><th>role</th><th>is_dlc</th></tr></thead><tbody><tr><td>Sir Ansbach</td><td>Pureblood Knight Captain (former), NPC Quest Related</td><td>1</td></tr><tr><td>Blaidd the Half-Wolf</td><td>Quest NPC and summon</td><td>0</td></tr><tr><td>Bloody Finger Hunter Yura</td><td>Quest NPC and Summonable Cooperator</td><td>0</td></tr><tr><td>Boc the Seamster</td><td>Garments Adjuster andQuest NPC</td><td>0</td></tr><tr><td>Brother Corhyn</td><td>Merchant and Quest NPC</td><td>0</td></tr><tr><td>D, Beholder of Death</td><td>Quest NPC and Summon</td><td>0</td></tr><tr><td>D, Hunter of the Dead</td><td>Quest NPC and Summon</td><td>0</td></tr><tr><td>Knight Diallos</td><td>Quest NPC</td><td>0</td></tr><tr><td>Dragon Communion Priestess</td><td>Questline Related</td><td>1</td></tr><tr><td>Dung Eater</td><td>Quest NPC, Invader, and Summon</td><td>0</td></tr><tr><td>Edgar</td><td>Morne Castellan, Quest NPC</td><td>0</td></tr><tr><td>Fia, Deathbed Companion</td><td>Quest NPC</td><td>0</td></tr><tr><td>Redmane Freyja</td><td>Cooperator, Questline Related</td><td>1</td></tr><tr><td>Goldmask</td><td>Quest NPC</td><td>0</td></tr><tr><td>Hyetta</td><td>Quest NPC</td><td>0</td></tr><tr><td>Igon</td><td>Drake Warrior, NPC Quest Related</td><td>1</td></tr><tr><td>Irina</td><td>Quest NPC</td><td>0</td></tr><tr><td>Jar Bairn</td><td>Quest NPC</td><td>0</td></tr><tr><td>Latenna</td><td>Quest NPC</td><td>0</td></tr><tr><td>Millicent</td><td>Quest NPC and Summonable Cooperator</td><td>0</td></tr><tr><td>Nepheli Loux, Warrior</td><td>Quest NPC and Summon</td><td>0</td></tr><tr><td>Patches</td><td>Boss, Merchant, Quest NPC, Summon</td><td>0</td></tr><tr><td>Preceptor Seluvis</td><td>Quest NPC and Merchant</td><td>0</td></tr><tr><td>Sorcerer Rogier</td><td>Merchant, Quest NPC, and Summon</td><td>0</td></tr><tr><td>Sorceress Sellen</td><td>Merchant and Quest NPC</td><td>0</td></tr><tr><td>St. Trina</td><td>NPC Quest Related</td><td>1</td></tr><tr><td>Tanith</td><td>Quest NPC</td><td>0</td></tr><tr><td>Thiollier</td><td>Merchant, NPC Quest Related</td><td>1</td></tr><tr><td>Three Fingers</td><td>Quest NPC</td><td>0</td></tr><tr><td>Wandering Artist Spirit</td><td>Quest NPC</td><td>0</td></tr><tr><td>Iji War Counselor & Carian Blacksmith</td><td>Blacksmith & Quest NPC</td><td>0</td></tr><tr><td>White Mask Varre</td><td>Guide and Quest NPC</td><td>0</td></tr><tr><td>Witch-Hunter Jerren</td><td>Quest NPC and Summon</td><td>0</td></tr></tbody></table></div>

# %%
# %sql
SELECT 
    n.npc_name,
    l.location_name,
    n.role
FROM eldenringcatalog.gold.dim_npcs n
LEFT JOIN eldenringcatalog.gold.bridge_location_npcs bln ON n.npc_name = bln.npc_name
LEFT JOIN eldenringcatalog.gold.dim_locations l ON bln.location_id = l.location_id
WHERE n.role LIKE '%Quest%'
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>npc_name</th><th>location_name</th><th>role</th></tr></thead><tbody><tr><td>Sir Ansbach</td><td>Enir-Ilim</td><td>Pureblood Knight Captain (former), NPC Quest Related</td></tr><tr><td>Blaidd the Half-Wolf</td><td>null</td><td>Quest NPC and summon</td></tr><tr><td>Bloody Finger Hunter Yura</td><td>Second Church of Marika</td><td>Quest NPC and Summonable Cooperator</td></tr><tr><td>Boc the Seamster</td><td>Leyndell, Royal Capital</td><td>Garments Adjuster andQuest NPC</td></tr><tr><td>Brother Corhyn</td><td>Leyndell, Royal Capital</td><td>Merchant and Quest NPC</td></tr><tr><td>D, Beholder of Death</td><td>null</td><td>Quest NPC and Summon</td></tr><tr><td>D, Hunter of the Dead</td><td>null</td><td>Quest NPC and Summon</td></tr><tr><td>Knight Diallos</td><td>null</td><td>Quest NPC</td></tr><tr><td>Dragon Communion Priestess</td><td>Grand Altar of Dragon Communion</td><td>Questline Related</td></tr><tr><td>Dung Eater</td><td>Subterranean Shunning-Grounds</td><td>Quest NPC, Invader, and Summon</td></tr><tr><td>Edgar</td><td>Castle Morne</td><td>Morne Castellan, Quest NPC</td></tr><tr><td>Fia, Deathbed Companion</td><td>null</td><td>Quest NPC</td></tr><tr><td>Redmane Freyja</td><td>Shadow Keep</td><td>Cooperator, Questline Related</td></tr><tr><td>Goldmask</td><td>Leyndell, Royal Capital</td><td>Quest NPC</td></tr><tr><td>Hyetta</td><td>Frenzied Flame Proscription</td><td>Quest NPC</td></tr><tr><td>Igon</td><td>null</td><td>Drake Warrior, NPC Quest Related</td></tr><tr><td>Irina</td><td>Bridge of Sacrifice</td><td>Quest NPC</td></tr><tr><td>Jar Bairn</td><td>Jarburg</td><td>Quest NPC</td></tr><tr><td>Latenna</td><td>Slumbering Wolf's Shack</td><td>Quest NPC</td></tr><tr><td>Millicent</td><td>Elphael Brace of the Haligtree</td><td>Quest NPC and Summonable Cooperator</td></tr><tr><td>Nepheli Loux, Warrior</td><td>null</td><td>Quest NPC and Summon</td></tr><tr><td>Patches</td><td>Volcano Manor</td><td>Boss, Merchant, Quest NPC, Summon</td></tr><tr><td>Preceptor Seluvis</td><td>Seluvis's Rise</td><td>Quest NPC and Merchant</td></tr><tr><td>Sorcerer Rogier</td><td>Stormveil Castle</td><td>Merchant, Quest NPC, and Summon</td></tr><tr><td>Sorceress Sellen</td><td>Raya Lucaria Academy</td><td>Merchant and Quest NPC</td></tr><tr><td>St. Trina</td><td>Stone Coffin Fissure</td><td>NPC Quest Related</td></tr><tr><td>Tanith</td><td>Volcano Manor</td><td>Quest NPC</td></tr><tr><td>Thiollier</td><td>Stone Coffin Fissure</td><td>Merchant, NPC Quest Related</td></tr><tr><td>Three Fingers</td><td>Frenzied Flame Proscription</td><td>Quest NPC</td></tr><tr><td>Wandering Artist Spirit</td><td>null</td><td>Quest NPC</td></tr><tr><td>Iji War Counselor & Carian Blacksmith</td><td>null</td><td>Blacksmith & Quest NPC</td></tr><tr><td>White Mask Varre</td><td>Rose Church</td><td>Guide and Quest NPC</td></tr><tr><td>Witch-Hunter Jerren</td><td>Redmane Castle</td><td>Quest NPC and Summon</td></tr><tr><td>Sir Ansbach</td><td>Belurat Tower Settlement</td><td>Pureblood Knight Captain (former), NPC Quest Related</td></tr><tr><td>Bloody Finger Hunter Yura</td><td>Raya Lucaria Academy</td><td>Quest NPC and Summonable Cooperator</td></tr><tr><td>Brother Corhyn</td><td>Leyndell, Ashen Capital</td><td>Merchant and Quest NPC</td></tr><tr><td>Dung Eater</td><td>Leyndell, Royal Capital</td><td>Quest NPC, Invader, and Summon</td></tr><tr><td>Redmane Freyja</td><td>Enir-Ilim</td><td>Cooperator, Questline Related</td></tr><tr><td>Goldmask</td><td>Leyndell, Ashen Capital</td><td>Quest NPC</td></tr><tr><td>Hyetta</td><td>Purified Ruins</td><td>Quest NPC</td></tr><tr><td>Irina</td><td>Bridge of Sacrifice</td><td>Quest NPC</td></tr><tr><td>Millicent</td><td>Dominula, Windmill Village</td><td>Quest NPC and Summonable Cooperator</td></tr><tr><td>Patches</td><td>The Shaded Castle</td><td>Boss, Merchant, Quest NPC, Summon</td></tr><tr><td>Preceptor Seluvis</td><td>R ...

# %% [markdown]
# # **📊 22: Summonable NPCs**

# %%
# %sql
SELECT npc_name, role, is_dlc
FROM eldenringcatalog.gold.dim_npcs
WHERE role LIKE '%Summon%';
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>npc_name</th><th>role</th><th>is_dlc</th></tr></thead><tbody><tr><td>Bloody Finger Hunter Yura</td><td>Quest NPC and Summonable Cooperator</td><td>0</td></tr><tr><td>D, Beholder of Death</td><td>Quest NPC and Summon</td><td>0</td></tr><tr><td>D, Hunter of the Dead</td><td>Quest NPC and Summon</td><td>0</td></tr><tr><td>Dung Eater</td><td>Quest NPC, Invader, and Summon</td><td>0</td></tr><tr><td>Finger Maiden Therolina</td><td>NPC Summon</td><td>0</td></tr><tr><td>Lionel the Lionhearted</td><td>Summon and Boss</td><td>0</td></tr><tr><td>Millicent</td><td>Quest NPC and Summonable Cooperator</td><td>0</td></tr><tr><td>Nepheli Loux, Warrior</td><td>Quest NPC and Summon</td><td>0</td></tr><tr><td>Patches</td><td>Boss, Merchant, Quest NPC, Summon</td><td>0</td></tr><tr><td>Shabriri</td><td>NPC and Summonable Cooperator</td><td>0</td></tr><tr><td>Sorcerer Rogier</td><td>Merchant, Quest NPC, and Summon</td><td>0</td></tr><tr><td>Witch-Hunter Jerren</td><td>Quest NPC and Summon</td><td>0</td></tr></tbody></table></div>

# %% [markdown]
# # **📊23: Boss-only locations (locations with bosses but few other entities)**

# %%
# %sql
WITH location_stats AS (
    SELECT 
        l.location_id,
        l.location_name,
        COALESCE(COUNT(DISTINCT bli.item_name), 0) AS item_count,
        COALESCE(COUNT(DISTINCT bln.npc_name), 0) AS npcs,
        COALESCE(COUNT(DISTINCT blb.boss_name), 0) AS bosses,
        COALESCE(COUNT(DISTINCT blc.creature_name), 0) AS creatures
    FROM eldenringcatalog.gold.dim_locations l
    LEFT JOIN eldenringcatalog.gold.bridge_location_items bli ON l.location_id = bli.location_id
    LEFT JOIN eldenringcatalog.gold.bridge_location_npcs bln ON l.location_id = bln.location_id
    LEFT JOIN eldenringcatalog.gold.bridge_location_bosses blb ON l.location_id = blb.location_id
    LEFT JOIN eldenringcatalog.gold.bridge_location_creatures blc ON l.location_id = blc.location_id
    GROUP BY l.location_id, l.location_name
)
SELECT location_name, bosses, item_count, creatures
FROM location_stats
WHERE bosses >= 1 AND item_count <= 5 AND npcs = 0;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>location_name</th><th>bosses</th><th>item_count</th><th>creatures</th></tr></thead><tbody><tr><td>Minor Erdtree (Caelid)</td><td>1</td><td>4</td><td>1</td></tr><tr><td>Ringleader's Evergaol</td><td>2</td><td>3</td><td>5</td></tr><tr><td>Eastern Nameless Mausoleum</td><td>1</td><td>5</td><td>0</td></tr><tr><td>Fort Faroth</td><td>1</td><td>5</td><td>3</td></tr><tr><td>Minor Erdtree (Mt. Gelmir)</td><td>1</td><td>0</td><td>0</td></tr><tr><td>Weeping Evergaol</td><td>1</td><td>2</td><td>0</td></tr><tr><td>Cuckoo's Evergaol</td><td>2</td><td>1</td><td>1</td></tr><tr><td>Caelem Ruins</td><td>1</td><td>2</td><td>2</td></tr><tr><td>Lord Contender's Evergaol</td><td>1</td><td>2</td><td>1</td></tr><tr><td>Cathedral of Dragon Communion (Caelid)</td><td>1</td><td>4</td><td>2</td></tr><tr><td>Minor Erdtree (Altus Plateau)</td><td>1</td><td>4</td><td>1</td></tr><tr><td>Divine Tower of East Altus</td><td>1</td><td>3</td><td>0</td></tr><tr><td>Malefactor's Evergaol</td><td>2</td><td>1</td><td>0</td></tr><tr><td>Royal Grave Evergaol</td><td>1</td><td>1</td><td>0</td></tr><tr><td>Shaman Village</td><td>1</td><td>2</td><td>0</td></tr><tr><td>Foot of the Jagged Peak</td><td>1</td><td>2</td><td>0</td></tr><tr><td>Minor Erdtree (Mountaintops East)</td><td>1</td><td>3</td><td>2</td></tr><tr><td>Minor Erdtree (Dragonbarrow)</td><td>1</td><td>2</td><td>0</td></tr><tr><td>Writheblood Ruins</td><td>1</td><td>3</td><td>4</td></tr><tr><td>Western Nameless Mausoleum</td><td>1</td><td>5</td><td>1</td></tr><tr><td>Northern Nameless Mausoleum</td><td>1</td><td>5</td><td>0</td></tr><tr><td>Stormhill Evergaol</td><td>1</td><td>2</td><td>0</td></tr><tr><td>Sellia Evergaol</td><td>1</td><td>1</td><td>0</td></tr></tbody></table></div>

# %% [markdown]
# # **📊 24: Safe locations (no bosses, no enemies)**

# %%
# %sql
WITH location_stats AS (
    SELECT 
        l.location_id,
        l.location_name,
        COALESCE(COUNT(DISTINCT bli.item_name), 0) AS item_count,
        COALESCE(COUNT(DISTINCT bln.npc_name), 0) AS npcs,
        COALESCE(COUNT(DISTINCT blb.boss_name), 0) AS bosses,
        COALESCE(COUNT(DISTINCT blc.creature_name), 0) AS creatures
    FROM eldenringcatalog.gold.dim_locations l
    LEFT JOIN eldenringcatalog.gold.bridge_location_items bli ON l.location_id = bli.location_id
    LEFT JOIN eldenringcatalog.gold.bridge_location_npcs bln ON l.location_id = bln.location_id
    LEFT JOIN eldenringcatalog.gold.bridge_location_bosses blb ON l.location_id = blb.location_id
    LEFT JOIN eldenringcatalog.gold.bridge_location_creatures blc ON l.location_id = blc.location_id
    GROUP BY l.location_id, l.location_name
)
SELECT location_name, item_count, npcs
FROM location_stats
WHERE bosses = 0 AND creatures = 0;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>location_name</th><th>item_count</th><th>npcs</th></tr></thead><tbody><tr><td>Slumbering Wolf's Shack</td><td>2</td><td>1</td></tr><tr><td>Gowry's Shack</td><td>6</td><td>2</td></tr><tr><td>Craftsman's Shack</td><td>1</td><td>0</td></tr><tr><td>Artist's Shack (Gravesite Plain)</td><td>1</td><td>0</td></tr><tr><td>Isolated Merchant's Shack Weeping Peninsula</td><td>12</td><td>1</td></tr><tr><td>Subterranean Shunning-Grounds</td><td>41</td><td>2</td></tr><tr><td>Church of Benediction</td><td>7</td><td>0</td></tr><tr><td>Boilprawn Shack</td><td>3</td><td>1</td></tr><tr><td>Deep Siofra Well</td><td>0</td><td>0</td></tr><tr><td>Run-Down Traveler's Rest</td><td>2</td><td>0</td></tr><tr><td>Grand Altar of Dragon Communion</td><td>4</td><td>1</td></tr><tr><td>Oridys's Rise</td><td>1</td><td>0</td></tr><tr><td>Whipping Hut</td><td>1</td><td>1</td></tr><tr><td>Ranni's Rise</td><td>1</td><td>4</td></tr><tr><td>Scadutree Chalice</td><td>3</td><td>0</td></tr><tr><td>Southern Nameless Mausoleum</td><td>9</td><td>0</td></tr><tr><td>Grand Lift of Dectus</td><td>2</td><td>0</td></tr><tr><td>Grand Lift of Rold</td><td>3</td><td>1</td></tr><tr><td>Deep Ainsel Well</td><td>0</td><td>0</td></tr><tr><td>Rabbath's Rise</td><td>3</td><td>0</td></tr><tr><td>Stormhill Shack</td><td>4</td><td>1</td></tr><tr><td>Starfall Crater</td><td>0</td><td>0</td></tr><tr><td>Suppressing Pillar</td><td>1</td><td>0</td></tr><tr><td>Grand Lift of Dectus</td><td>2</td><td>0</td></tr><tr><td>Minor Erdtree Church</td><td>3</td><td>0</td></tr><tr><td>Leyndell Colosseum</td><td>0</td><td>0</td></tr><tr><td>Converted Tower</td><td>3</td><td>0</td></tr><tr><td>Divine Tower of West Altus</td><td>1</td><td>0</td></tr><tr><td>Renna's Rise</td><td>1</td><td>0</td></tr></tbody></table></div>

# %% [markdown]
# # **📊 25: Locations with unique items (appearing only once)**

# %%
# %sql
WITH item_counts AS (
    SELECT item_name, COUNT(*) AS location_count
    FROM eldenringcatalog.gold.bridge_location_items
    GROUP BY item_name
    HAVING COUNT(*) = 1
)
SELECT 
    ic.item_name,
    l.location_name
FROM item_counts ic
INNER JOIN eldenringcatalog.gold.bridge_location_items bli ON ic.item_name = bli.item_name
INNER JOIN eldenringcatalog.gold.dim_locations l ON bli.location_id = l.location_id
LIMIT 50;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>item_name</th><th>location_name</th></tr></thead><tbody><tr><td>Ailment Talisman</td><td>Abandoned Ailing Village</td></tr><tr><td>Greater Potentates Cookbook (10)</td><td>Abandoned Ailing Village</td></tr><tr><td>Incursion Painting</td><td>Artist's Shack (Gravesite Plain)</td></tr><tr><td>Shadow Realm Rune 3</td><td>Belurat Gaol</td></tr><tr><td>Greatjar</td><td>Belurat Gaol</td></tr><tr><td>Greater Potentates Cookbook (11)</td><td>Belurat Gaol</td></tr><tr><td>Demi-Human Swordsman Yosh</td><td>Belurat Gaol</td></tr><tr><td>Dried Bouquet</td><td>Belurat Tower Settlement</td></tr><tr><td>Stimulating Boluse</td><td>Belurat Tower Settlement</td></tr><tr><td>Bone Bow</td><td>Belurat Tower Settlement</td></tr><tr><td>Poisoned Hand</td><td>Belurat Tower Settlement</td></tr><tr><td>Divine Beast Head</td><td>Belurat Tower Settlement</td></tr><tr><td>Watchful Spirit</td><td>Belurat Tower Settlement</td></tr><tr><td>Ash of War: Shriek of Sorrow</td><td>Belurat Tower Settlement</td></tr><tr><td>Scorpion Liver</td><td>Belurat Tower Settlement</td></tr><tr><td>Horned Warriors Sword</td><td>Belurat Tower Settlement</td></tr><tr><td>Storeroom Key</td><td>Belurat Tower Settlement</td></tr><tr><td>Well Depths Key</td><td>Belurat Tower Settlement</td></tr><tr><td>Scorpion Stew</td><td>Belurat Tower Settlement</td></tr><tr><td>Tower of Shadow Message</td><td>Belurat Tower Settlement</td></tr><tr><td>Remembrance of the Dancing Lion</td><td>Belurat Tower Settlement</td></tr><tr><td>Rellanas Cameo</td><td>Castle Ensis</td></tr><tr><td>Shadow Realm Rune 2</td><td>Castle Ensis</td></tr><tr><td>Shadow Realm Rune 4</td><td>Castle Ensis</td></tr><tr><td>Drawstring Royal Magic Grease</td><td>Castle Ensis</td></tr><tr><td>Milady</td><td>Castle Ensis</td></tr><tr><td>Wolf Crest Shield</td><td>Castle Ensis</td></tr><tr><td>Moonrithylls Knight Sword</td><td>Castle Ensis</td></tr><tr><td>Carian Sorcery Sword</td><td>Castle Ensis</td></tr><tr><td>Glintstone Trio</td><td>Castle Ensis</td></tr><tr><td>Glintslab Fly</td><td>Castle Ensis</td></tr><tr><td>Dagger</td><td>Castle Ensis</td></tr><tr><td>Lazuli Robe</td><td>Castle Ensis</td></tr><tr><td>Heavy Crossbow</td><td>Castle Ensis</td></tr><tr><td>Royal Magic Grease</td><td>Castle Ensis</td></tr><tr><td>Message from Leda</td><td>Castle Ensis</td></tr><tr><td>Loyal Knights Cookbook</td><td>Castle Ensis</td></tr><tr><td>Remembrance of the Twin Moon Knight</td><td>Castle Ensis</td></tr><tr><td>Ash of War: Wing Stance</td><td>Castle Ensis</td></tr><tr><td>Monks Missive</td><td>Castle Ensis</td></tr><tr><td>May the Best Win</td><td>Castle Ensis</td></tr><tr><td>Cross Map</td><td>Castle Ensis</td></tr><tr><td>New Cross Map</td><td>Castle Ensis</td></tr><tr><td>Blessed Blue Dew Talisman</td><td>Church of Benediction</td></tr><tr><td>Oathseeker Knight Greaves</td><td>Church of Benediction</td></tr><tr><td>Oathseeker Knight Gauntlets</td><td>Church of Benediction</td></tr><tr><td>Oathseeker Knight Armor</td><td>Church of Benediction</td></tr><tr><td>Oathseeker Knight Helm</td><td>Church of Benediction</td></tr><tr><td>Pata</td><td>Church of Benediction</td></tr><tr><td>Dragon-Hunters Great Katana</td><td>Dragon's Pit</td></tr></tbody></table></div>

# %% [markdown]
# # **📊 Question 26: Most common items across locations**

# %%
# %sql
SELECT item_name, COUNT(*) AS location_count
FROM eldenringcatalog.gold.bridge_location_items
GROUP BY item_name
ORDER BY location_count DESC
LIMIT 30;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>item_name</th><th>location_count</th></tr></thead><tbody><tr><td>Stonesword Key</td><td>41</td></tr><tr><td>Rowa Fruit</td><td>39</td></tr><tr><td>Rune Arc</td><td>32</td></tr><tr><td>Mushroom</td><td>29</td></tr><tr><td>Furlcalling Finger Remedy</td><td>23</td></tr><tr><td>Golden Seed</td><td>22</td></tr><tr><td>Grave Violet</td><td>21</td></tr><tr><td>Smoldering Butterfly</td><td>20</td></tr><tr><td>Arteria Leaf</td><td>19</td></tr><tr><td>Trinas Lily</td><td>19</td></tr><tr><td>Erdleaf Flower</td><td>18</td></tr><tr><td>Herba</td><td>17</td></tr><tr><td>Nascent Butterfly</td><td>17</td></tr><tr><td>Smithing Stone (1)</td><td>16</td></tr><tr><td>Smithing Stone (7)</td><td>16</td></tr><tr><td>Golden Rune (1)</td><td>16</td></tr><tr><td>Golden Rune (10)</td><td>14</td></tr><tr><td>Silver Firefly</td><td>14</td></tr><tr><td>Sacred Tear</td><td>13</td></tr><tr><td>Smithing Stone (6)</td><td>13</td></tr><tr><td>Scadutree Fragment</td><td>13</td></tr><tr><td>Cave Moss</td><td>13</td></tr><tr><td>Budding Cave Moss</td><td>12</td></tr><tr><td>Smithing Stone (2)</td><td>12</td></tr><tr><td>Smithing Stone (8)</td><td>12</td></tr><tr><td>Root Resin</td><td>12</td></tr><tr><td>Smithing Stone (5)</td><td>12</td></tr><tr><td>Smithing Stone 4</td><td>12</td></tr><tr><td>Tarnished Golden Sunflower</td><td>12</td></tr><tr><td>Smithing Stone (4)</td><td>11</td></tr></tbody></table></div>

# %% [markdown]
# # **📊 28: Create exploration priority list**

# %%
# %sql
WITH location_stats AS (
    SELECT 
        l.location_id,
        l.location_name,
        COALESCE(COUNT(DISTINCT bli.item_name), 0) AS item_count,
        COALESCE(COUNT(DISTINCT bln.npc_name), 0) AS npcs,
        COALESCE(COUNT(DISTINCT blb.boss_name), 0) AS bosses,
        COALESCE(COUNT(DISTINCT blc.creature_name), 0) AS creatures
    FROM eldenringcatalog.gold.dim_locations l
    LEFT JOIN eldenringcatalog.gold.bridge_location_items bli ON l.location_id = bli.location_id
    LEFT JOIN eldenringcatalog.gold.bridge_location_npcs bln ON l.location_id = bln.location_id
    LEFT JOIN eldenringcatalog.gold.bridge_location_bosses blb ON l.location_id = blb.location_id
    LEFT JOIN eldenringcatalog.gold.bridge_location_creatures blc ON l.location_id = blc.location_id
    GROUP BY l.location_id, l.location_name
)
SELECT 
    location_name,
    item_count,
    npcs,
    bosses,
    creatures,
    ROUND((item_count * 1.0) + (npcs * 10) + (bosses * 15) + (creatures * 0.3), 2) AS priority_score
FROM location_stats
ORDER BY priority_score DESC
LIMIT 20;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>location_name</th><th>item_count</th><th>npcs</th><th>bosses</th><th>creatures</th><th>priority_score</th></tr></thead><tbody><tr><td>Leyndell, Royal Capital</td><td>75</td><td>5</td><td>6</td><td>1</td><td>215.3</td></tr><tr><td>Volcano Manor</td><td>52</td><td>5</td><td>6</td><td>11</td><td>195.3</td></tr><tr><td>Stormveil Castle</td><td>82</td><td>4</td><td>4</td><td>8</td><td>184.4</td></tr><tr><td>Roundtable Hold</td><td>10</td><td>14</td><td>2</td><td>0</td><td>180.0</td></tr><tr><td>Raya Lucaria Academy</td><td>63</td><td>6</td><td>3</td><td>22</td><td>174.6</td></tr><tr><td>Seethewater Cave</td><td>18</td><td>13</td><td>1</td><td>6</td><td>164.8</td></tr><tr><td>Enir-Ilim</td><td>53</td><td>6</td><td>3</td><td>9</td><td>160.7</td></tr><tr><td>Shadow Keep</td><td>93</td><td>4</td><td>1</td><td>14</td><td>152.2</td></tr><tr><td>Bestial Sanctum</td><td>12</td><td>11</td><td>2</td><td>0</td><td>152.0</td></tr><tr><td>Leyndell, Ashen Capital</td><td>14</td><td>3</td><td>6</td><td>3</td><td>134.9</td></tr><tr><td>Mistwood</td><td>27</td><td>3</td><td>3</td><td>14</td><td>106.2</td></tr><tr><td>Castle Ensis</td><td>47</td><td>2</td><td>2</td><td>12</td><td>100.6</td></tr><tr><td>Siofra River</td><td>36</td><td>3</td><td>2</td><td>13</td><td>99.9</td></tr><tr><td>Belurat Tower Settlement</td><td>52</td><td>3</td><td>1</td><td>8</td><td>99.4</td></tr><tr><td>Ainsel River</td><td>29</td><td>1</td><td>4</td><td>1</td><td>99.3</td></tr><tr><td>Sealed Tunnel</td><td>13</td><td>7</td><td>1</td><td>4</td><td>99.2</td></tr><tr><td>Nokron, Eternal City</td><td>39</td><td>1</td><td>3</td><td>7</td><td>96.1</td></tr><tr><td>Redmane Castle</td><td>19</td><td>3</td><td>3</td><td>6</td><td>95.8</td></tr><tr><td>Cathedral of Manus Metyr</td><td>14</td><td>2</td><td>4</td><td>3</td><td>94.9</td></tr><tr><td>Stormhill</td><td>14</td><td>3</td><td>3</td><td>14</td><td>93.2</td></tr></tbody></table></div>
